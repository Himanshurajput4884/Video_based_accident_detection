# %%
import cv2
import os

def split_videos_to_frames(video_folder, new_folder, max_frames_per_video=50):
    # Iterate through all files in the video folder
    for video_name in os.listdir(video_folder):
        video_path = os.path.join(video_folder, video_name)

        # Check if the file is a video (you can customize this condition)
        if video_name.lower().endswith(('.mp4', '.avi', '.mkv', '.mov')):
            # Create a subfolder in the new folder with the video name
            video_name_without_extension = os.path.splitext(video_name)[0]
            video_output_folder = os.path.join(new_folder, video_name_without_extension)
            os.makedirs(video_output_folder, exist_ok=True)

            # Open the video file
            cap = cv2.VideoCapture(video_path)

            # Get video information
            frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

            # Determine the number of frames to extract
            num_frames_to_extract = min(frame_count, max_frames_per_video)

            # Iterate through each frame and save it in the video's output folder
            for frame_number in range(num_frames_to_extract):
                ret, frame = cap.read()
                if not ret:
                    break

                # Save the frame as an image
                frame_filename = f"img_{frame_number}.jpg"
                frame_path = os.path.join(video_output_folder, frame_filename)
                cv2.imwrite(frame_path, frame)

                print(f"Saved frame: {frame_path}")

            # Release the video capture object
            cap.release()

# Example usage:
video_folder_path = "C:/Minor12/feature_extractor/videos"
new_folder_path = "C:/Minor12/feature_extractor/dataset/train"

split_videos_to_frames(video_folder_path, new_folder_path, max_frames_per_video=50)
# Out:
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_0.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_1.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_2.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_3.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_4.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_5.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_6.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_7.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_8.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_9.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_10.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_11.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_12.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_13.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_14.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_15.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_16.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_17.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_18.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_19.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_20.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_21.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_22.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_23.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_24.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_25.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_26.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_27.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_28.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_29.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_30.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_31.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_32.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_33.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_34.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_35.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_36.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_37.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_38.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_39.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_40.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_41.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_42.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_43.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_44.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_45.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_46.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_47.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_48.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus1\img_49.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_0.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_1.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_2.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_3.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_4.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_5.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_6.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_7.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_8.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_9.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_10.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_11.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_12.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_13.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_14.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_15.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_16.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_17.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_18.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_19.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_20.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_21.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_22.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_23.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_24.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_25.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_26.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_27.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_28.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_29.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_30.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_31.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_32.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_33.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_34.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_35.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_36.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_37.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_38.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_39.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_40.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_41.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_42.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_43.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_44.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_45.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_46.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_47.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_48.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus2\img_49.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_0.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_1.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_2.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_3.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_4.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_5.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_6.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_7.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_8.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_9.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_10.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_11.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_12.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_13.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_14.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_15.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_16.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_17.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_18.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_19.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_20.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_21.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_22.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_23.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_24.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_25.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_26.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_27.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_28.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_29.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_30.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_31.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_32.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_33.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_34.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_35.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_36.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_37.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_38.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_39.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_40.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_41.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_42.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_43.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_44.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_45.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_46.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_47.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_48.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus3\img_49.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_0.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_1.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_2.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_3.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_4.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_5.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_6.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_7.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_8.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_9.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_10.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_11.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_12.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_13.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_14.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_15.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_16.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_17.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_18.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_19.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_20.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_21.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_22.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_23.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_24.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_25.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_26.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_27.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_28.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_29.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_30.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_31.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_32.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_33.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_34.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_35.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_36.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_37.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_38.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_39.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_40.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_41.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_42.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_43.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_44.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_45.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_46.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_47.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_48.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus4\img_49.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_0.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_1.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_2.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_3.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_4.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_5.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_6.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_7.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_8.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_9.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_10.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_11.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_12.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_13.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_14.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_15.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_16.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_17.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_18.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_19.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_20.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_21.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_22.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_23.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_24.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_25.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_26.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_27.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_28.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_29.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_30.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_31.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_32.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_33.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_34.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_35.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_36.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_37.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_38.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_39.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_40.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_41.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_42.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_43.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_44.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_45.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_46.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_47.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_48.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus5\img_49.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_0.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_1.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_2.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_3.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_4.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_5.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_6.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_7.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_8.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_9.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_10.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_11.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_12.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_13.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_14.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_15.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_16.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_17.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_18.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_19.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_20.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_21.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_22.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_23.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_24.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_25.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_26.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_27.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_28.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_29.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_30.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_31.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_32.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_33.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_34.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_35.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_36.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_37.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_38.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_39.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_40.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_41.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_42.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_43.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_44.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_45.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_46.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_47.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_48.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus6\img_49.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_0.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_1.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_2.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_3.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_4.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_5.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_6.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_7.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_8.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_9.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_10.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_11.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_12.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_13.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_14.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_15.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_16.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_17.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_18.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_19.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_20.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_21.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_22.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_23.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_24.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_25.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_26.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_27.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_28.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_29.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_30.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_31.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_32.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_33.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_34.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_35.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_36.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_37.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_38.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_39.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_40.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_41.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_42.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_43.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_44.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_45.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_46.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_47.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_48.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\bus7\img_49.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_0.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_1.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_2.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_3.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_4.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_5.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_6.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_7.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_8.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_9.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_10.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_11.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_12.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_13.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_14.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_15.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_16.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_17.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_18.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_19.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_20.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_21.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_22.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_23.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_24.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_25.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_26.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_27.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_28.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_29.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_30.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_31.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_32.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_33.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_34.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_35.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_36.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_37.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_38.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_39.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_40.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_41.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_42.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_43.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_44.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_45.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_46.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_47.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_48.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car1\img_49.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_0.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_1.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_2.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_3.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_4.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_5.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_6.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_7.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_8.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_9.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_10.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_11.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_12.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_13.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_14.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_15.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_16.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_17.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_18.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_19.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_20.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_21.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_22.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_23.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_24.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_25.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_26.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_27.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_28.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_29.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_30.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_31.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_32.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_33.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_34.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_35.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_36.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_37.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_38.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_39.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_40.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_41.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_42.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_43.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_44.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_45.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_46.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_47.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_48.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car2\img_49.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_0.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_1.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_2.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_3.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_4.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_5.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_6.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_7.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_8.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_9.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_10.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_11.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_12.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_13.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_14.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_15.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_16.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_17.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_18.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_19.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_20.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_21.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_22.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_23.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_24.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_25.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_26.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_27.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_28.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_29.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_30.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_31.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_32.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_33.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_34.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_35.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_36.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_37.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_38.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_39.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_40.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_41.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_42.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_43.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_44.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_45.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_46.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_47.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_48.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\car3\img_49.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_0.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_1.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_2.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_3.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_4.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_5.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_6.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_7.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_8.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_9.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_10.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_11.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_12.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_13.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_14.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_15.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_16.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_17.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_18.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_19.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_20.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_21.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_22.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_23.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_24.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_25.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_26.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_27.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_28.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_29.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_30.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_31.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_32.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_33.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_34.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_35.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_36.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_37.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_38.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_39.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_40.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_41.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_42.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_43.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_44.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_45.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_46.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_47.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_48.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon\img_49.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_0.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_1.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_2.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_3.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_4.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_5.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_6.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_7.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_8.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_9.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_10.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_11.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_12.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_13.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_14.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_15.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_16.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_17.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_18.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_19.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_20.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_21.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_22.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_23.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_24.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_25.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_26.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_27.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_28.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_29.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_30.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_31.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_32.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_33.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_34.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_35.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_36.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_37.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_38.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_39.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_40.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_41.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_42.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_43.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_44.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_45.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_46.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_47.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_48.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_49.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_0.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_1.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_2.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_3.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_4.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_5.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_6.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_7.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_8.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_9.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_10.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_11.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_12.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_13.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_14.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_15.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_16.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_17.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_18.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_19.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_20.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_21.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_22.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_23.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_24.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_25.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_26.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_27.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_28.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_29.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_30.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_31.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_32.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_33.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_34.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_35.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_36.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_37.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_38.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_39.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_40.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_41.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_42.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_43.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_44.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_45.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_46.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_47.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_48.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_49.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\pickup1\img_0.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\pickup1\img_1.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\pickup1\img_2.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\pickup1\img_3.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\pickup1\img_4.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\pickup1\img_5.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\pickup1\img_6.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\pickup1\img_7.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\pickup1\img_8.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\pickup1\img_9.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\pickup1\img_10.jpg
# ...
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck2\img_34.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck2\img_35.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck2\img_36.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck2\img_37.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck2\img_38.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck2\img_39.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck2\img_40.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck2\img_41.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck2\img_42.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck2\img_43.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck2\img_44.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck2\img_45.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck2\img_46.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck2\img_47.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck2\img_48.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck2\img_49.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_0.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_1.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_2.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_3.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_4.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_5.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_6.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_7.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_8.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_9.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_10.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_11.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_12.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_13.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_14.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_15.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_16.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_17.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_18.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_19.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_20.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_21.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_22.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_23.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_24.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_25.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_26.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_27.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_28.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_29.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_30.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_31.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_32.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_33.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_34.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_35.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_36.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_37.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_38.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_39.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_40.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_41.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_42.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_43.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_44.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_45.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_46.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_47.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_48.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck3\img_49.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_0.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_1.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_2.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_3.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_4.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_5.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_6.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_7.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_8.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_9.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_10.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_11.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_12.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_13.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_14.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_15.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_16.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_17.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_18.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_19.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_20.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_21.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_22.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_23.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_24.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_25.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_26.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_27.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_28.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_29.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_30.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_31.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_32.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_33.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_34.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_35.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_36.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_37.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_38.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_39.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_40.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_41.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_42.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_43.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_44.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_45.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_46.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_47.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_48.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\truck4\img_49.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_0.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_1.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_2.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_3.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_4.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_5.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_6.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_7.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_8.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_9.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_10.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_11.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_12.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_13.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_14.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_15.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_16.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_17.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_18.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_19.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_20.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_21.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_22.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_23.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_24.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_25.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_26.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_27.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_28.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_29.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_30.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_31.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_32.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_33.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_34.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_35.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_36.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_37.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_38.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_39.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_40.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_41.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_42.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_43.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_44.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_45.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_46.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_47.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_48.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna1\img_49.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_0.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_1.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_2.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_3.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_4.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_5.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_6.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_7.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_8.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_9.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_10.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_11.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_12.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_13.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_14.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_15.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_16.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_17.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_18.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_19.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_20.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_21.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_22.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_23.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_24.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_25.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_26.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_27.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_28.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_29.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_30.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_31.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_32.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_33.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_34.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_35.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_36.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_37.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_38.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_39.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_40.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_41.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_42.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_43.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_44.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_45.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_46.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_47.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_48.jpg
# Saved frame: C:/Minor12/feature_extractor/dataset/train\verna2\img_49.jpg

# %%
import os
import random
import shutil

def random_images_from_folders(input_folder_path, output_folder_path, max_images):
    # Iterate through all folders in the input folder
    for child_folder_name in os.listdir(input_folder_path):
        child_folder_path = os.path.join(input_folder_path, child_folder_name)

        # Check if the item in the input folder is a directory
        if os.path.isdir(child_folder_path):
            # Create a corresponding folder in the output folder
            output_child_folder_path = os.path.join(output_folder_path, child_folder_name)
            os.makedirs(output_child_folder_path, exist_ok=True)

            # List all image files in the child folder
            image_files = [f for f in os.listdir(child_folder_path) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

            # Randomly select max_images number of images
            selected_images = random.sample(image_files, min(max_images, len(image_files)))

            # Copy the selected images to the output folder
            for image_name in selected_images:
                source_image_path = os.path.join(child_folder_path, image_name)
                destination_image_path = os.path.join(output_child_folder_path, image_name)
                shutil.copyfile(source_image_path, destination_image_path)

                print(f"Copied: {source_image_path} -> {destination_image_path}")

# Example usage:
input_folder_path = "C:/Minor12/feature_extractor/dataset/train"
output_folder_path = "C:/Minor12/feature_extractor/dataset/validate"
max_images_per_folder = 5

random_images_from_folders(input_folder_path, output_folder_path, max_images_per_folder)
# Out:
# Copied: C:/Minor12/feature_extractor/dataset/train\bus1\img_13.jpg -> C:/Minor12/feature_extractor/dataset/validate\bus1\img_13.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\bus1\img_31.jpg -> C:/Minor12/feature_extractor/dataset/validate\bus1\img_31.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\bus1\img_34.jpg -> C:/Minor12/feature_extractor/dataset/validate\bus1\img_34.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\bus1\img_16.jpg -> C:/Minor12/feature_extractor/dataset/validate\bus1\img_16.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\bus1\img_47.jpg -> C:/Minor12/feature_extractor/dataset/validate\bus1\img_47.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\bus2\img_25.jpg -> C:/Minor12/feature_extractor/dataset/validate\bus2\img_25.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\bus2\img_33.jpg -> C:/Minor12/feature_extractor/dataset/validate\bus2\img_33.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\bus2\img_32.jpg -> C:/Minor12/feature_extractor/dataset/validate\bus2\img_32.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\bus2\img_48.jpg -> C:/Minor12/feature_extractor/dataset/validate\bus2\img_48.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\bus2\img_29.jpg -> C:/Minor12/feature_extractor/dataset/validate\bus2\img_29.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\bus3\img_45.jpg -> C:/Minor12/feature_extractor/dataset/validate\bus3\img_45.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\bus3\img_18.jpg -> C:/Minor12/feature_extractor/dataset/validate\bus3\img_18.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\bus3\img_19.jpg -> C:/Minor12/feature_extractor/dataset/validate\bus3\img_19.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\bus3\img_17.jpg -> C:/Minor12/feature_extractor/dataset/validate\bus3\img_17.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\bus3\img_43.jpg -> C:/Minor12/feature_extractor/dataset/validate\bus3\img_43.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\bus4\img_26.jpg -> C:/Minor12/feature_extractor/dataset/validate\bus4\img_26.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\bus4\img_24.jpg -> C:/Minor12/feature_extractor/dataset/validate\bus4\img_24.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\bus4\img_27.jpg -> C:/Minor12/feature_extractor/dataset/validate\bus4\img_27.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\bus4\img_17.jpg -> C:/Minor12/feature_extractor/dataset/validate\bus4\img_17.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\bus4\img_19.jpg -> C:/Minor12/feature_extractor/dataset/validate\bus4\img_19.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\bus5\img_43.jpg -> C:/Minor12/feature_extractor/dataset/validate\bus5\img_43.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\bus5\img_49.jpg -> C:/Minor12/feature_extractor/dataset/validate\bus5\img_49.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\bus5\img_0.jpg -> C:/Minor12/feature_extractor/dataset/validate\bus5\img_0.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\bus5\img_4.jpg -> C:/Minor12/feature_extractor/dataset/validate\bus5\img_4.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\bus5\img_6.jpg -> C:/Minor12/feature_extractor/dataset/validate\bus5\img_6.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\bus6\img_40.jpg -> C:/Minor12/feature_extractor/dataset/validate\bus6\img_40.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\bus6\img_19.jpg -> C:/Minor12/feature_extractor/dataset/validate\bus6\img_19.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\bus6\img_14.jpg -> C:/Minor12/feature_extractor/dataset/validate\bus6\img_14.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\bus6\img_48.jpg -> C:/Minor12/feature_extractor/dataset/validate\bus6\img_48.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\bus6\img_12.jpg -> C:/Minor12/feature_extractor/dataset/validate\bus6\img_12.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\bus7\img_9.jpg -> C:/Minor12/feature_extractor/dataset/validate\bus7\img_9.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\bus7\img_13.jpg -> C:/Minor12/feature_extractor/dataset/validate\bus7\img_13.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\bus7\img_42.jpg -> C:/Minor12/feature_extractor/dataset/validate\bus7\img_42.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\bus7\img_0.jpg -> C:/Minor12/feature_extractor/dataset/validate\bus7\img_0.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\bus7\img_2.jpg -> C:/Minor12/feature_extractor/dataset/validate\bus7\img_2.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\car1\img_37.jpg -> C:/Minor12/feature_extractor/dataset/validate\car1\img_37.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\car1\img_35.jpg -> C:/Minor12/feature_extractor/dataset/validate\car1\img_35.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\car1\img_39.jpg -> C:/Minor12/feature_extractor/dataset/validate\car1\img_39.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\car1\img_21.jpg -> C:/Minor12/feature_extractor/dataset/validate\car1\img_21.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\car1\img_3.jpg -> C:/Minor12/feature_extractor/dataset/validate\car1\img_3.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\car2\img_12.jpg -> C:/Minor12/feature_extractor/dataset/validate\car2\img_12.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\car2\img_24.jpg -> C:/Minor12/feature_extractor/dataset/validate\car2\img_24.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\car2\img_15.jpg -> C:/Minor12/feature_extractor/dataset/validate\car2\img_15.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\car2\img_49.jpg -> C:/Minor12/feature_extractor/dataset/validate\car2\img_49.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\car2\img_36.jpg -> C:/Minor12/feature_extractor/dataset/validate\car2\img_36.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\car3\img_22.jpg -> C:/Minor12/feature_extractor/dataset/validate\car3\img_22.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\car3\img_15.jpg -> C:/Minor12/feature_extractor/dataset/validate\car3\img_15.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\car3\img_49.jpg -> C:/Minor12/feature_extractor/dataset/validate\car3\img_49.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\car3\img_8.jpg -> C:/Minor12/feature_extractor/dataset/validate\car3\img_8.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\car3\img_46.jpg -> C:/Minor12/feature_extractor/dataset/validate\car3\img_46.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\gwagon\img_47.jpg -> C:/Minor12/feature_extractor/dataset/validate\gwagon\img_47.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\gwagon\img_37.jpg -> C:/Minor12/feature_extractor/dataset/validate\gwagon\img_37.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\gwagon\img_26.jpg -> C:/Minor12/feature_extractor/dataset/validate\gwagon\img_26.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\gwagon\img_9.jpg -> C:/Minor12/feature_extractor/dataset/validate\gwagon\img_9.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\gwagon\img_27.jpg -> C:/Minor12/feature_extractor/dataset/validate\gwagon\img_27.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_37.jpg -> C:/Minor12/feature_extractor/dataset/validate\gwagon1\img_37.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_36.jpg -> C:/Minor12/feature_extractor/dataset/validate\gwagon1\img_36.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_49.jpg -> C:/Minor12/feature_extractor/dataset/validate\gwagon1\img_49.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_0.jpg -> C:/Minor12/feature_extractor/dataset/validate\gwagon1\img_0.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\gwagon1\img_32.jpg -> C:/Minor12/feature_extractor/dataset/validate\gwagon1\img_32.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_49.jpg -> C:/Minor12/feature_extractor/dataset/validate\mercedes1\img_49.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_33.jpg -> C:/Minor12/feature_extractor/dataset/validate\mercedes1\img_33.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_45.jpg -> C:/Minor12/feature_extractor/dataset/validate\mercedes1\img_45.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_19.jpg -> C:/Minor12/feature_extractor/dataset/validate\mercedes1\img_19.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\mercedes1\img_29.jpg -> C:/Minor12/feature_extractor/dataset/validate\mercedes1\img_29.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\pickup1\img_17.jpg -> C:/Minor12/feature_extractor/dataset/validate\pickup1\img_17.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\pickup1\img_49.jpg -> C:/Minor12/feature_extractor/dataset/validate\pickup1\img_49.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\pickup1\img_27.jpg -> C:/Minor12/feature_extractor/dataset/validate\pickup1\img_27.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\pickup1\img_0.jpg -> C:/Minor12/feature_extractor/dataset/validate\pickup1\img_0.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\pickup1\img_2.jpg -> C:/Minor12/feature_extractor/dataset/validate\pickup1\img_2.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\pickup2\img_12.jpg -> C:/Minor12/feature_extractor/dataset/validate\pickup2\img_12.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\pickup2\img_44.jpg -> C:/Minor12/feature_extractor/dataset/validate\pickup2\img_44.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\pickup2\img_46.jpg -> C:/Minor12/feature_extractor/dataset/validate\pickup2\img_46.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\pickup2\img_15.jpg -> C:/Minor12/feature_extractor/dataset/validate\pickup2\img_15.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\pickup2\img_25.jpg -> C:/Minor12/feature_extractor/dataset/validate\pickup2\img_25.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\scorpio\img_45.jpg -> C:/Minor12/feature_extractor/dataset/validate\scorpio\img_45.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\scorpio\img_18.jpg -> C:/Minor12/feature_extractor/dataset/validate\scorpio\img_18.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\scorpio\img_40.jpg -> C:/Minor12/feature_extractor/dataset/validate\scorpio\img_40.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\scorpio\img_24.jpg -> C:/Minor12/feature_extractor/dataset/validate\scorpio\img_24.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\scorpio\img_28.jpg -> C:/Minor12/feature_extractor/dataset/validate\scorpio\img_28.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\scorpio2\img_22.jpg -> C:/Minor12/feature_extractor/dataset/validate\scorpio2\img_22.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\scorpio2\img_42.jpg -> C:/Minor12/feature_extractor/dataset/validate\scorpio2\img_42.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\scorpio2\img_36.jpg -> C:/Minor12/feature_extractor/dataset/validate\scorpio2\img_36.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\scorpio2\img_37.jpg -> C:/Minor12/feature_extractor/dataset/validate\scorpio2\img_37.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\scorpio2\img_45.jpg -> C:/Minor12/feature_extractor/dataset/validate\scorpio2\img_45.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\swift1\img_6.jpg -> C:/Minor12/feature_extractor/dataset/validate\swift1\img_6.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\swift1\img_42.jpg -> C:/Minor12/feature_extractor/dataset/validate\swift1\img_42.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\swift1\img_19.jpg -> C:/Minor12/feature_extractor/dataset/validate\swift1\img_19.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\swift1\img_40.jpg -> C:/Minor12/feature_extractor/dataset/validate\swift1\img_40.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\swift1\img_8.jpg -> C:/Minor12/feature_extractor/dataset/validate\swift1\img_8.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\swift2\img_12.jpg -> C:/Minor12/feature_extractor/dataset/validate\swift2\img_12.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\swift2\img_44.jpg -> C:/Minor12/feature_extractor/dataset/validate\swift2\img_44.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\swift2\img_28.jpg -> C:/Minor12/feature_extractor/dataset/validate\swift2\img_28.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\swift2\img_34.jpg -> C:/Minor12/feature_extractor/dataset/validate\swift2\img_34.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\swift2\img_23.jpg -> C:/Minor12/feature_extractor/dataset/validate\swift2\img_23.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\truck1\img_21.jpg -> C:/Minor12/feature_extractor/dataset/validate\truck1\img_21.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\truck1\img_22.jpg -> C:/Minor12/feature_extractor/dataset/validate\truck1\img_22.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\truck1\img_45.jpg -> C:/Minor12/feature_extractor/dataset/validate\truck1\img_45.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\truck1\img_48.jpg -> C:/Minor12/feature_extractor/dataset/validate\truck1\img_48.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\truck1\img_18.jpg -> C:/Minor12/feature_extractor/dataset/validate\truck1\img_18.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\truck2\img_29.jpg -> C:/Minor12/feature_extractor/dataset/validate\truck2\img_29.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\truck2\img_38.jpg -> C:/Minor12/feature_extractor/dataset/validate\truck2\img_38.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\truck2\img_46.jpg -> C:/Minor12/feature_extractor/dataset/validate\truck2\img_46.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\truck2\img_9.jpg -> C:/Minor12/feature_extractor/dataset/validate\truck2\img_9.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\truck2\img_48.jpg -> C:/Minor12/feature_extractor/dataset/validate\truck2\img_48.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\truck3\img_46.jpg -> C:/Minor12/feature_extractor/dataset/validate\truck3\img_46.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\truck3\img_1.jpg -> C:/Minor12/feature_extractor/dataset/validate\truck3\img_1.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\truck3\img_40.jpg -> C:/Minor12/feature_extractor/dataset/validate\truck3\img_40.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\truck3\img_0.jpg -> C:/Minor12/feature_extractor/dataset/validate\truck3\img_0.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\truck3\img_23.jpg -> C:/Minor12/feature_extractor/dataset/validate\truck3\img_23.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\truck4\img_26.jpg -> C:/Minor12/feature_extractor/dataset/validate\truck4\img_26.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\truck4\img_37.jpg -> C:/Minor12/feature_extractor/dataset/validate\truck4\img_37.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\truck4\img_29.jpg -> C:/Minor12/feature_extractor/dataset/validate\truck4\img_29.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\truck4\img_44.jpg -> C:/Minor12/feature_extractor/dataset/validate\truck4\img_44.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\truck4\img_12.jpg -> C:/Minor12/feature_extractor/dataset/validate\truck4\img_12.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\verna1\img_31.jpg -> C:/Minor12/feature_extractor/dataset/validate\verna1\img_31.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\verna1\img_45.jpg -> C:/Minor12/feature_extractor/dataset/validate\verna1\img_45.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\verna1\img_4.jpg -> C:/Minor12/feature_extractor/dataset/validate\verna1\img_4.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\verna1\img_14.jpg -> C:/Minor12/feature_extractor/dataset/validate\verna1\img_14.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\verna1\img_25.jpg -> C:/Minor12/feature_extractor/dataset/validate\verna1\img_25.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\verna2\img_2.jpg -> C:/Minor12/feature_extractor/dataset/validate\verna2\img_2.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\verna2\img_46.jpg -> C:/Minor12/feature_extractor/dataset/validate\verna2\img_46.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\verna2\img_15.jpg -> C:/Minor12/feature_extractor/dataset/validate\verna2\img_15.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\verna2\img_42.jpg -> C:/Minor12/feature_extractor/dataset/validate\verna2\img_42.jpg
# Copied: C:/Minor12/feature_extractor/dataset/train\verna2\img_0.jpg -> C:/Minor12/feature_extractor/dataset/validate\verna2\img_0.jpg
